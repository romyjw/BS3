# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
from torch import autograd as Grad

import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.cm as cm
import matplotlib.tri as mtri
import matplotlib


#import plotly.graph_objects as go

import ipywidgets as widgets
from IPython.display import display
import trimesh

import random
import math

import time
import os
import json

import copy



import open3d as o3d
print(o3d.__path__)
print('Using open3d version',o3d.__version__)
# Suppress Open3D warnings
o3d.utility.set_verbosity_level(o3d.utility.VerbosityLevel.Error)



from visuals import *


from bns_utils import *
from mesh_processing import *

import differential
import importlib
importlib.reload(differential)
from differential import *

two_pi = 2*torch.pi
diffmod = DifferentialModule()

# Set device priority: MPS > CUDA > CPU

if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")


device = torch.device("cpu")


#device = torch.device('cpu')
print(f"Using device: {device}")


def check_for_nans(tensor, name='tensor'):
    if torch.isnan(tensor).any():
        print(f"\n⚠️ NaNs detected in {name}!\n")
        print(f"{name} stats -- min: {tensor.min().item()}, max: {tensor.max().item()}, mean: {tensor.mean().item()}")
        raise ValueError(f"NaNs found in {name}")
# Out:
# ['/Users/romywilliamson/miniconda3/envs/bens/lib/python3.8/site-packages/open3d']
# Using open3d version 0.18.0
# device: cpu
# Using device: mps
# device: cpu
# Using device: cpu
# /Users/romywilliamson/miniconda3/envs/bens/lib/python3.8/site-packages/torch/nn/utils/weight_norm.py:134: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# /Users/romywilliamson/Documents/BNS/bns/implicit_reps.py:67: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(weights, map_location=device))

# %%
with open("configs/torus100.json", "r") as f:
    config_dict = json.load(f)


blend_type = config_dict['blend_type']
shape_id = config_dict['shape_id']
coarse_patches_id = config_dict['coarse_patches_id']
angle_flag = config_dict['angle_flag']
overlap_param = config_dict['overlap_param']    # 0.15470053837 < v < 0.73205080756
degree = config_dict['degree'] #polynomial degree
global_scale = config_dict['global_scale']

layer_sizes=[2,3,4]
posenc=None

# %%
import BNS
importlib.reload(BNS)
from BNS import BNS


# instantiate
bns = BNS(layer_sizes, from_file=True, coarse_patches_id=coarse_patches_id, posenc=posenc, angle_flag=angle_flag, overlap_param = overlap_param, degree=degree, global_scale=global_scale, blend_type=blend_type, device=device)


#bns.load_poly_coeffs('models/sphere_normals_reg_0409.pth')
#bns.load_poly_coeffs('models/torus_normals_reg_0309.pth')
#bns.load_poly_coeffs('models/6octsphere.pth')
bns.load_poly_coeffs('models/torus7oct.pth')
# Out:
# Using open3d version at ['/Users/romywilliamson/miniconda3/envs/bens/lib/python3.8/site-packages/open3d']
# Using open3d version at ['/Users/romywilliamson/miniconda3/envs/bens/lib/python3.8/site-packages/open3d']
# Assiging a halfedge to each vertex.
# Preparing V_he for halfedge mesh
# Prepared V_he for halfedge mesh.
#
# Optimising V_he.
# Finished optimising V_he.
#
# base triangle verts torch.float32
# Computing onering data.
# Computing rotations.
# /Users/romywilliamson/Documents/BNS/bns/BNS.py:404: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   poly_coeffs_data = torch.load(filename, map_location=self.device)

# %%
import visuals
importlib.reload(visuals)
from visuals import *



bns.reset()

deformed_bns = copy.deepcopy(bns)



T = torch.zeros_like(bns.V)
#T[3,:] = torch.tensor([-0.2, 0.0, 0.0 ])
#T[3,:] = torch.tensor([-1.2, 0.0, 0.0 ])
T[0,:] = torch.tensor([0.5, 0.0, 0.0 ])

scale = 1.0

deformed_bns.V = scale * deformed_bns.V + T

#deformed_bns.compute_fixed_rotations()


elastic_energy_visualiser = Elastic_energy_visualiser(bns, deformed_bns, mesh_res=5, test_flag='poly',just_onering=False, blend_type=blend_type, use_original_mesh=False,
                               show_on_coarse=False, alpha=1.0, beta=1.0, energy_visual_scale=0.5)

elastic_energy_visualiser.compute_quantities()
elastic_energy_visualiser.show_bns()
# Out:
# /Users/romywilliamson/miniconda3/envs/bens/lib/python3.8/site-packages/torch/nn/utils/weight_norm.py:134: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# /Users/romywilliamson/Documents/BNS/bns/implicit_reps.py:67: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(weights, map_location=device))
# device: cpu
# /Users/romywilliamson/Documents/BNS/bns/differential.py:160: UserWarning: Using torch.cross without specifying the dim arg is deprecated.
# Please either pass the dim explicitly or simply use torch.linalg.cross.
# The default value of dim will change to agree with that of linalg.cross in a future release. (Triggered internally at /Users/runner/miniforge3/conda-bld/libtorch_1724557166878/work/aten/src/ATen/native/Cross.cpp:66.)
#   cross_prod = torch.cross(Su, Sv)
# 💡 Using custom lighting direction (-0.5, -0.8, -1.0)
# ✅ Screenshot saved: output/cts_area_dist_x.png
# ✅ Screenshot saved: output/cts_area_dist_y.png
# ✅ Screenshot saved: output/cts_area_dist_z.png
# 💡 Using custom lighting direction (-0.5, -0.8, -1.0)
# ✅ Screenshot saved: elastic energy_x.png
# ✅ Screenshot saved: elastic energy_y.png
# ✅ Screenshot saved: elastic energy_z.png

# %%
# generate training samples
training_sample_dict = bns.compute_samples(num_samples=1000000, avoid_corners=True)
coarse = training_sample_dict['coarse_embedding']

# %%
training_sample_dict['uv'].shape
# Out:
# torch.Size([100, 1000000, 2])

# %%
from tqdm import trange

uv = training_sample_dict['uv']
chunk = 10000
B, N, _ = uv.shape

area_dists = []
for i in trange(0, N, chunk, desc="Computing area distortion"):
    wrt = uv[:, i:i+chunk].clone().detach().requires_grad_(True)
    out = bns(wrt, test_flag='poly')
    area_dists.append(diffmod.compute_area_distortion(out=out, wrt=wrt).detach())

area_dist_full = torch.cat(area_dists, dim=1)
print("Final shape:", area_dist_full.shape)
# Out:
# Computing area distortion: 100%|██████████████| 100/100 [11:47<00:00,  7.08s/it]
# Final shape: torch.Size([100, 1000000])

# %%
training_sample_dict['sample_weighting'] = area_dist_full * 4 / np.sqrt(3)

# %%
bns.reset()

deformed_bns = copy.deepcopy(bns)



T = torch.zeros_like(bns.V)
#T[3,:] = torch.tensor([-0.2, 0.0, 0.0 ])
#T[3,:] = torch.tensor([-1.2, 0.0, 0.0 ])
T[0,:] = torch.tensor([0.5, 0.0, 0.0 ])

scale = 1.0

deformed_bns.V = scale * deformed_bns.V + T

# %%
############### initial training settings #####################

epoch=0

losses=[]
fractional_epochs=[]
eps = 1.0e-6

epochs=[]
times=[]
num_patches = bns.num_patches

loss=99999


flexible_params = []
for name, param in deformed_bns.named_parameters():
    split_name = name.split('.')
    if split_name[0] == 'poly_coeffs' and split_name[1]=='0':
        flexible_params.append(param)
        print(name)

        
optimizer = optim.Adam(flexible_params, lr=0.001)
# Out:
# poly_coeffs.0.0
# poly_coeffs.0.1
# poly_coeffs.0.2
# poly_coeffs.0.3
# poly_coeffs.0.4
# poly_coeffs.0.5
# poly_coeffs.0.6
# poly_coeffs.0.7
# poly_coeffs.0.8
# poly_coeffs.0.9

# %%
flexible_params
# Out:
# [Parameter containing:
#  tensor([ 0.0616,  0.0282, -0.0012], requires_grad=True),
#  Parameter containing:
#  tensor([ 0.9362,  0.1391, -0.0326], requires_grad=True),
#  Parameter containing:
#  tensor([-0.1077,  0.5580, -0.0300], requires_grad=True),
#  Parameter containing:
#  tensor([0.0543, 0.5151, 1.7156], requires_grad=True),
#  Parameter containing:
#  tensor([ 1.0869, -1.5764,  0.4672], requires_grad=True),
#  Parameter containing:
#  tensor([-0.7405, -0.5891, -1.1824], requires_grad=True),
#  Parameter containing:
#  tensor([ 1.6980,  0.9639, -0.0084], requires_grad=True),
#  Parameter containing:
#  tensor([ 1.2425,  0.8552, -2.1009], requires_grad=True),
#  Parameter containing:
#  tensor([1.2527, 1.9393, 1.1145], requires_grad=True),
#  Parameter containing:
#  tensor([-0.5908, -0.4025,  1.8176], requires_grad=True)]

# %%
import time
import torch
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output

import implicit_reps
import importlib

# Reload module (useful during development)
importlib.reload(implicit_reps)
from implicit_reps import *


##################### Training Loop ###########################

def train_batch_loop(
    lr: float = 0.01,
    batch_size: int = 10_000,
    min_loss: float = 5e-4,
    batch_print_rate: int = 100,
    batch_plot_rate: int = 10,
    epoch_print_rate: int = 1,
    epoch_save_rate: int = 1,
    epoch_plot_rate: int = 1,
    plot: bool = False,
    flag: str = "poly",
    just_onering: bool = False,
):
    """
    Batch training loop for deformation optimization.

    Args:
        lr (float): Learning rate for optimizer.
        batch_size (int): Number of samples per batch.
        min_loss (float): Stop training once loss drops below this value.
        batch_print_rate (int): Print frequency within batches.
        batch_plot_rate (int): Plot frequency within batches.
        epoch_print_rate (int): Print frequency per epoch.
        epoch_save_rate (int): Model checkpoint frequency.
        epoch_plot_rate (int): Epoch-level plotting frequency.
        plot (bool): Whether to show live plots.
        flag (str): Model evaluation flag.
        just_onering (bool): Whether to restrict training to a single 1-ring.
    """
    global optimizer, losses, times, epoch, loss, num_patches, eps, shape_id

    # Shorthand
    bns1, bns2 = bns, deformed_bns

    # Update learning rate dynamically
    for g in optimizer.param_groups:
        g["lr"] = lr

    # Select indices: one-ring neighborhood or full mesh
    if just_onering:
        select_patch_indices = torch.tensor(
            bns.onerings[0]["triangles"], dtype=torch.long, device=bns.device
        )
    else:
        select_patch_indices = torch.arange(
            bns.F.shape[0], dtype=torch.long, device=bns.device
        )

    seqs, total_points = t_train.shape[0], t_train.shape[1]

    while loss > min_loss:
        perm = torch.randperm(total_points)
        epoch_loss = 0.0

        for i in range(0, total_points, batch_size):
            batch_start = time.time()

            # Sample mini-batch
            idx = perm[i : i + batch_size]
            batch_t = t_train[:, idx, :].clone().detach().requires_grad_(True)
            batch_sample_weighting = training_sample_dict['sample_weighting'][:, idx]

            optimizer.zero_grad()

            # Forward pass
            out1, _ = bns1(
                batch_t, select_patch_indices=select_patch_indices,
                return_onering_coords=True, test_flag=flag
            )
            out2, _ = bns2(
                batch_t, select_patch_indices=select_patch_indices,
                return_onering_coords=True, test_flag=flag
            )

            # Elastic energy density
            elastic_energy_density, total_energy, FFF = diffmod.elastic_energy_density(
                out1=out1, out2=out2, wrt=batch_t,
                alpha=1.0, beta=1.0, inverse_J1=None
            )


            
            #compute more accurate total energy
            #print(elastic_energy_density.shape, batch_sample_weighting.shape)
            #total_energy = (elastic_energy_density * batch_sample_weighting).mean()

            batch_loss = total_energy

            # Backprop
            batch_loss.backward()

            # Gradient clipping
            torch.nn.utils.clip_grad_norm_(bns.parameters(), max_norm=1.0)

            # NaN check
            for name, param in bns.named_parameters():
                if param.grad is not None and torch.isnan(param.grad).any():
                    raise ValueError(f"NaN gradient detected in {name}")

            optimizer.step()

            # Stats
            epoch_loss += batch_loss * batch_t.shape[1]
            batch_time = time.time() - batch_start

            losses.append(batch_loss.item())
            times.append(batch_time)
            fractional_epochs.append(epoch + i / total_points)

            

            # Logging
            if i % batch_print_rate == 0:
                print(f"Batch {i}, Loss: {batch_loss:.8f}, Batch Time: {batch_time:.4f}s")

        # Epoch update
        loss = epoch_loss / total_points
        if epoch % epoch_print_rate == 0:
            print(f"Epoch {epoch}, Loss: {loss.item():.8f}")

        if epoch % epoch_save_rate == 0:
            bns.save_poly_coeffs("models/temp.pth")
            print("Saved checkpoint.")

        epoch += 1
# Out:
# device: cpu

# %%
t_train = training_sample_dict['uv']

# %%
train_batch_loop(lr=0.1, batch_size=1000, min_loss=0.0, batch_plot_rate=10, plot=True)
# Out:
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 0, Loss: 1.01591277, Batch Time: 4.7555s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 1000, Loss: 0.18643476, Batch Time: 4.5874s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 2000, Loss: 0.02062021, Batch Time: 4.7689s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 3000, Loss: 0.00294113, Batch Time: 4.4626s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 4000, Loss: 0.00492047, Batch Time: 4.5407s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 5000, Loss: 0.01901391, Batch Time: 4.5019s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 6000, Loss: 0.05585039, Batch Time: 4.5234s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 7000, Loss: 0.10502319, Batch Time: 4.6077s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 8000, Loss: 0.13958439, Batch Time: 4.5532s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 9000, Loss: 0.14691471, Batch Time: 4.5916s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 10000, Loss: 0.11569305, Batch Time: 4.7142s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 11000, Loss: 0.08085866, Batch Time: 4.6305s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 12000, Loss: 0.04512568, Batch Time: 4.6429s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 13000, Loss: 0.02215923, Batch Time: 4.7283s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 14000, Loss: 0.01148022, Batch Time: 4.7377s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 15000, Loss: 0.00562276, Batch Time: 4.6901s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 16000, Loss: 0.00316431, Batch Time: 4.6148s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 17000, Loss: 0.00234850, Batch Time: 4.6368s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 18000, Loss: 0.00259803, Batch Time: 4.6560s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 19000, Loss: 0.00358977, Batch Time: 4.6149s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 20000, Loss: 0.00575260, Batch Time: 4.6234s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 21000, Loss: 0.00798980, Batch Time: 4.6673s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 22000, Loss: 0.01074918, Batch Time: 4.6614s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 23000, Loss: 0.01294187, Batch Time: 4.6803s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 24000, Loss: 0.01453594, Batch Time: 4.6340s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 25000, Loss: 0.01602945, Batch Time: 4.6349s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 26000, Loss: 0.01517525, Batch Time: 4.7131s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 27000, Loss: 0.01287916, Batch Time: 4.7222s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 28000, Loss: 0.01118841, Batch Time: 4.7075s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 29000, Loss: 0.00839691, Batch Time: 4.6494s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 30000, Loss: 0.00684464, Batch Time: 4.8066s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 31000, Loss: 0.00497490, Batch Time: 4.6019s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 32000, Loss: 0.00381008, Batch Time: 4.7666s
# torch.Size([100, 1000]) torch.Size([100, 1000])
# Batch 33000, Loss: 0.00289414, Batch Time: 4.8991s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 train_batch_loop(lr=0.1, batch_size=1000, min_loss=0.0, batch_plot_rate=10, plot=True)
#
# Cell In[63], line 92, in train_batch_loop(lr, batch_size, min_loss, batch_print_rate, batch_plot_rate, epoch_print_rate, epoch_save_rate, epoch_plot_rate, plot, flag, just_onering)
#      86 out2, _ = bns2(
#      87     batch_t, select_patch_indices=select_patch_indices,
#      88     return_onering_coords=True, test_flag=flag
#      89 )
#      91 # Elastic energy density
# ---> 92 elastic_energy_density, total_energy, FFF = diffmod.elastic_energy_density(
#      93     out1=out1, out2=out2, wrt=batch_t,
#      94     alpha=1.0, beta=1.0, inverse_J1=None
#      95 )
#      99 #compute more accurate total energy
#     100 print(elastic_energy_density.shape, batch_sample_weighting.shape)
#
# File ~/Documents/BNS/bns/differential.py:148, in DifferentialModule.elastic_energy_density(self, out1, out2, wrt, inverse_J1, alpha, beta)
#     145 def elastic_energy_density(self, out1=None, out2=None, wrt=None, inverse_J1=None , alpha=1.0, beta=1.0):
#     146
#     147     # Compute gradients in batch
# --> 148     grads1 = self.gradient(
#     149         out=out1, wrt=wrt
#     150     )
#     152     grads2 = self.gradient(
#     153         out=out2, wrt=wrt
#     154     )
#     157     # Construct rotation R (P, N, 3, 2)
#
# File ~/Documents/BNS/bns/differential.py:39, in DifferentialModule.gradient(self, out, wrt, allow_unused)
#      36 for r in range(R):
#      37     grad_out = torch.ones_like(out[:, :, r])
# ---> 39     grad_r = Grad(
#      40         outputs=out[:, :, r],
#      41         inputs=wrt,
#      42         grad_outputs=grad_out,
#      43         create_graph=True,
#      44         allow_unused=allow_unused,
#      45     )[0]  # Shape: [B, N, C]
#      47     gradients.append(grad_r.unsqueeze(2))  # [B, N, 1, C]
#      49 jacobian = torch.cat(gradients, dim=2)  # [B, N, R, C]
#
# File ~/miniconda3/envs/bens/lib/python3.8/site-packages/torch/autograd/__init__.py:436, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     432     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     433         grad_outputs_
#     434     )
#     435 else:
# --> 436     result = _engine_run_backward(
#     437         t_outputs,
#     438         grad_outputs_,
#     439         retain_graph,
#     440         create_graph,
#     441         inputs,
#     442         allow_unused,
#     443         accumulate_grad=False,
#     444     )
#     445 if materialize_grads:
#     446     if any(
#     447         result[i] is None and not is_tensor_like(inputs[i])
#     448         for i in range(len(inputs))
#     449     ):
#
# File ~/miniconda3/envs/bens/lib/python3.8/site-packages/torch/autograd/graph.py:768, in _engine_run_backward(t_outputs, *args, **kwargs)
#     766     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     767 try:
# --> 768     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     769         t_outputs, *args, **kwargs
#     770     )  # Calls into the C++ engine to run the backward pass
#     771 finally:
#     772     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import visuals
importlib.reload(visuals)
from visuals import *


elastic_energy_visualiser = Elastic_energy_visualiser(bns, deformed_bns, mesh_res=6, test_flag='poly',just_onering=False, blend_type=blend_type, use_original_mesh=False,
                               show_on_coarse=False, alpha=1.0, beta=1.0, energy_visual_scale=0.5)

elastic_energy_visualiser.compute_quantities()
elastic_energy_visualiser.show_bns()
# Out:
# device: cpu
# 💡 Using custom lighting direction (-0.5, -0.8, -1.0)
# ✅ Screenshot saved: output/cts_area_dist_x.png
# ✅ Screenshot saved: output/cts_area_dist_y.png
# ✅ Screenshot saved: output/cts_area_dist_z.png
# 💡 Using custom lighting direction (-0.5, -0.8, -1.0)
# ✅ Screenshot saved: elastic energy_x.png
# ✅ Screenshot saved: elastic energy_y.png
# ✅ Screenshot saved: elastic energy_z.png

# %%
######### save model ############
ans = input('Would you like to save the model? y/n')
if ans=='y':
    filename = input('What filename would you like to save it as (no extension)?')
    bns.save_poly_coeffs('models/'+filename+'.pth')
    print('Saved model parameters as '+filename+'.pth')
