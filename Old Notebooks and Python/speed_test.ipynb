# %%
import time

my_list = [i for i in range(100000000)]


start = time.time()
for i in range(len(my_list)):
    a = (my_list[i])
end=time.time()
print(end-start)



start = time.time()
for i,_ in enumerate(my_list):
    a = _
end=time.time()
print(end-start)
# Out:
# 4.119293928146362
# 4.25566291809082
