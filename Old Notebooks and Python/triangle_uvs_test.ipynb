# %%
import open3d as o3d
import numpy as np

filename = 'patches/sphere2_4patch/0_param.obj'
mesh_o3d = o3d.io.read_triangle_mesh(filename)

print(np.asarray(mesh_o3d.triangle_uvs).shape)
print(np.asarray(mesh_o3d.triangles).shape)
# Out:
# (294, 2)
# (98, 3)

# %%
tm = trimesh.load('patches/sphere2/0.obj')
mesh_o3d= o3d.geometry.TriangleMesh('patches/sphere2/0.obj')
mesh_o3d.vertices=o3d.utility.Vector3dVector( tm.vertices )
mesh_o3d.triangles=o3d.utility.Vector3iVector( tm.faces)

# %%
98*3
# Out:
# 294
