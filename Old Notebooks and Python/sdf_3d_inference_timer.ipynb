# %%
import torch
import numpy
from implicit_reps import *
import time

# %%
points = torch.zeros(1,10, 3)
t_0 = time.time()
sdf = deepsdf(points, ckpt_path='sdf_weights/spike_best_epoch31.ckpt')
t_1 = time.time()

print('time:', t_1-t_0)
# Out:
# time: 7.1651129722595215
